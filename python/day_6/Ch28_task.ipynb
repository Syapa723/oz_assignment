# %% [markdown]
# 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
def min_max(*nums) :
    nums_tuple = tuple(nums)
    return(min(nums_tuple),max(nums_tuple))

min_max(10,28,89)
# Out:
# (10, 89)
