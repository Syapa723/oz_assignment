# %% [markdown]
# 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
def print_name(name = None) :
    if name :
        print(name)

    else :
        print('익명')


print_name('세영')
# Out:
# 세영
