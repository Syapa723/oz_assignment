# %% [markdown]
# 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %%
# 제너레이터 부분이 이해가 잘 되지 않아서 답안따라서 코드를 작성했는데
# 아직 yield 함수의 메커니즘이 잘 이해가 되질 않습니다..ㅠㅠ

# def odd_numbers(n) :
#     for i in range(n) :
#         if i % 2 != 0 :
#             yield i

# for num in odd_numbers(10) :
#     print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
